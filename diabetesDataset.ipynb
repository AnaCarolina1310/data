# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
def annot (plot, pos):
  if pos == 'v':
    for p in plot.patches:
         plot.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
         ha='center', va='center', xytext=(0, 10), textcoords='offset points')
  if pos == 'h':
     for p in plot.patches:
         plot.annotate(p.get_width(), xy=(p.get_width(), p.get_y()+p.get_height()/2),xytext=(5, 10),
         textcoords='offset points', ha="left", va="center")

# %%
df=pd.read_csv('./diabetes_prediction_dataset.csv')

# %%
df.head(5)
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
df.shape
# Out:
# (100000, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB

# %%
df.columns.tolist()
# Out:
# ['gender',
#  'age',
#  'hypertension',
#  'heart_disease',
#  'smoking_history',
#  'bmi',
#  'HbA1c_level',
#  'blood_glucose_level',
#  'diabetes']

# %%
df.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %% [markdown]
# GENDER

# %%
gender_bar=sns.countplot(x='gender', data=df)
gender_bar.set_title('Distribution of gender')
gender_bar.set_ylabel('Frequency')
gender_bar.set_xlabel('Gender')
annot(gender_bar, 'v')

# %% [markdown]
# AGE

# %%
df['age'].describe()
# Out:
# count    100000.000000
# mean         41.885856
# std          22.516840
# min           0.080000
# 25%          24.000000
# 50%          43.000000
# 75%          60.000000
# max          80.000000
# Name: age, dtype: float64

# %%
age_hist= sns.histplot(data=df['age'], kde=True)
age_hist.set_title('Distribution of age')
age_hist.set_xlabel('Age')
age_hist.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# HYPERTENSION

# %%
hypertension_bar=sns.countplot(x='hypertension', data=df)
hypertension_bar.set_title('Distribution of hypertension')
hypertension_bar.set_ylabel('hypertension')
annot(hypertension_bar, 'v')

# %% [markdown]
# HEART DISEASE

# %%
heart_disease_bar=sns.countplot(x='heart_disease', data=df)
heart_disease_bar.set_title('Distribution of heart disease')
heart_disease_bar.set_ylabel('Heart disease')
annot(heart_disease_bar, 'v')

# %% [markdown]
# SMOKING HISTORY

# %%
smoking_history_bar=sns.countplot(y='smoking_history', data=df)
smoking_history_bar.set_title('Distribution of smoking history')
smoking_history_bar.set_xlabel('Frequency')
smoking_history_bar.set_ylabel('Smoking history')
annot(smoking_history_bar, 'h')

# %%
df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %% [markdown]
# BMI

# %%
df['bmi'].describe()
# Out:
# count    100000.000000
# mean         27.320767
# std           6.636783
# min          10.010000
# 25%          23.630000
# 50%          27.320000
# 75%          29.580000
# max          95.690000
# Name: bmi, dtype: float64

# %%
bmi_hist= sns.histplot(data=df['bmi'], kde=True)
bmi_hist.set_title('Distribution of BMI')
bmi_hist.set_xlabel('BMI')
bmi_hist.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
box_bmi=sns.boxplot(y='bmi', data=df)
box_bmi.set_title('Distribution of bmi')
box_bmi.set_ylabel('BMI')
# Out:
# Text(0, 0.5, 'BMI')

# %% [markdown]
# HEMOGLOBINA GLICOSILADA

# %%
df['HbA1c_level'].describe()
# Out:
# count    100000.000000
# mean          5.527507
# std           1.070672
# min           3.500000
# 25%           4.800000
# 50%           5.800000
# 75%           6.200000
# max           9.000000
# Name: HbA1c_level, dtype: float64

# %%
HbA1c_level_hist= sns.histplot(data=df['HbA1c_level'], kde=True)
HbA1c_level_hist.set_title('Distribution of hemoglobina glicosilada')
HbA1c_level_hist.set_xlabel('Hemoglobina glicosilada')
HbA1c_level_hist.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
box_HbA1c_level=sns.boxplot(y='HbA1c_level', data=df)
box_HbA1c_level.set_title('Distribution of hemoglobina glicosilada')
box_HbA1c_level.set_ylabel('Hemoglobina glicosilada')
# Out:
# Text(0, 0.5, 'Hemoglobina glicosilada')

# %% [markdown]
# BLOOD GLUCOSE LEVEL

# %%
blood_glucose_level_hist= sns.histplot(data=df['blood_glucose_level'], kde=True)
blood_glucose_level_hist.set_title('Distribution of hemoglobina glicosilada')
blood_glucose_level_hist.set_xlabel('Hemoglobina glicosilada')
blood_glucose_level_hist.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# Diabetes

# %%
diabetes_bar=sns.countplot(x='diabetes', data=df)
diabetes_bar.set_title('Distribution of diabetes')
diabetes_bar.set_ylabel('Diabetes')
annot(diabetes_bar, 'v')
