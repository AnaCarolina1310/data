# %%
import numpy as np 
import pandas as pd
import seaborn as snb
import matplotlib.pyplot as plt

# %%
train= pd.read_csv('hotels_train.csv')
test = pd.read_csv('hotels_test.csv')

# %%
train.head(2)
# Out:
#           hotel  lead_time  arrival_date_year arrival_date_month  \
# 0    City Hotel         49               2016          September
# 1  Resort Hotel          4               2015            October
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        37                          5
# 1                        44                         31
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  ...  \
# 0                        1                     2       1       0.0  ...
# 1                        0                     1       2       0.0  ...
#
#    agent company days_in_waiting_list customer_type    adr  \
# 0    9.0     NaN                    0     Transient  115.5
# 1    NaN     NaN                    0     Transient   42.0
#
#    required_car_parking_spaces  total_of_special_requests  \
# 0                            0                          1
# 1                            1                          0
#
#    reservation_status_date                                    id is_canceled
# 0               2016-08-25  7aa4cc6b-b92c-4061-b21d-4f9e0cac4689           1
# 1               2015-11-01  b1428f80-c56c-4ae4-91a9-6962edae08b1           0
#
# [2 rows x 32 columns]

# %% [markdown]
# # a) Exploración inicial

# %%
train.shape
# Out:
# (61913, 32)

# %%
train.columns.tolist()
# Out:
# ['hotel',
#  'lead_time',
#  'arrival_date_year',
#  'arrival_date_month',
#  'arrival_date_week_number',
#  'arrival_date_day_of_month',
#  'stays_in_weekend_nights',
#  'stays_in_week_nights',
#  'adults',
#  'children',
#  'babies',
#  'meal',
#  'country',
#  'market_segment',
#  'distribution_channel',
#  'is_repeated_guest',
#  'previous_cancellations',
#  'previous_bookings_not_canceled',
#  'reserved_room_type',
#  'assigned_room_type',
#  'booking_changes',
#  'deposit_type',
#  'agent',
#  'company',
#  'days_in_waiting_list',
#  'customer_type',
#  'adr',
#  'required_car_parking_spaces',
#  'total_of_special_requests',
#  'reservation_status_date',
#  'id',
#  'is_canceled']

# %% [markdown]
# Descripción:
# - Hotel : Hotel ( Resort Hotel o City Hotel)
# - Is_canceled : Valor que indica si la reserva fue cancelada (1) o no (0)
# - Lead_time : Número de días transcurridos entre la fecha de entrada de la reserva en el PMS y la fecha de llegada
# - Arrival_date_year : Año de la fecha de llegada
# - Arrival_date_month : Mes de la fecha de llegada
# - Arrival_date_week_number : Número de semana del año de la fecha de llegada
# - Arrival_date_day_of_month : Día de la fecha de llegada
# - Stays_in_weekend_nights : Número de noches de fin de semana (sábado o domingo) que el huésped se alojó o reservó para alojarse en el hotel
# - Stays_in_week_nights : Número de noches entre semana (de lunes a viernes) que el cliente se alojó o reservó en el hotel
# - Adults : Número de adultos
# - Niños : Número de niños
# - Babies : Número de bebés
# - Comida : Tipo de comida reservada. Las categorías se presentan en paquetes de comidas de hospitalidad estándar: Sin definir/SC sin paquete de comidas; BB - Alojamiento y desayuno; HB - Media pensión (desayuno y otra comida - normalmente cena); FB - Pensión completa (desayuno, almuerzo y cena).
# - País : País de origen. Las categorías se representan en el formato ISO 3155-3:2013
# - Segmento_mercado : Designación del segmento de mercado. En las categorías, el término "TA" significa "agencias de viajes" y "TO" significa "tour operadores".
# - Distribution_channel : Canal de distribución de las reservas. El término "TA" significa "Agencias de viajes" y "TO" significa "Tour operadores".
# - Is_repeated_guest : Valor que indica si el nombre de la reserva era de un huésped repetido (1) o no (0)
# - Previous_cancellations : Número de reservas anteriores canceladas por el cliente antes de la reserva actual
# - Previous_bookings_not_canceled : Número de reservas anteriores no canceladas por el cliente antes de la reserva actual
# - Reserved_room_type : Código del tipo de habitación reservada. El código se presenta en lugar de la designación por razones de anonimato.
# - Tipo_habitación_asignada : Código del tipo de habitación asignado a la reserva. A veces, el tipo de habitación asignada difiere del tipo de habitación reservada por motivos de funcionamiento del hotel (por ejemplo, exceso de reservas) o a petición del cliente. El código se presenta en lugar de la designación por razones de anonimato.
# - Booking_changes : Número de cambios/enmiendas realizados en la reserva desde el momento en que se introdujo la reserva en el PMS hasta el momento de la facturación o la cancelación.
# - Deposit_type : Indicación de si el cliente ha efectuado un depósito para garantizar la reserva. Esta variable puede ser de tres tipos
# - Agent : ID de la agencia de viajes que efectuó la reserva
# - Empresa : ID de la empresa/entidad que realizó la reserva o responsable del pago de la reserva. Se presenta el ID en lugar de la designación por razones de anonimato
# - Days_in_waiting_list : Número de días que la reserva estuvo en lista de espera antes de ser confirmada al cliente
# - Customer_type : Tipo de reserva, asumiendo una de las cuatro categorías: Contract - cuando la reserva tiene asociada una adjudicación u otro tipo de contrato; Group - cuando la reserva está asociada a un grupo; Transient - cuando la reserva no forma parte de un grupo o contrato, y no está asociada a otra reserva transient; Transient-party - cuando la reserva es transient, pero está asociada al menos a otra reserva transient
# - Adr : Tarifa media diaria definida dividiendo la suma de todas las transacciones de alojamiento por el número total de noches de estancia
# - Required_car_parking_spaces : Número de plazas de aparcamiento requeridas por el cliente
# - Total_of_special_requests : Número de peticiones especiales realizadas por el cliente (por ejemplo, cama doble o piso alto)
# - Reservation_status_date : Fecha del último estado de la reserva.

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61913 entries, 0 to 61912
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           61913 non-null  object
#  1   lead_time                       61913 non-null  int64
#  2   arrival_date_year               61913 non-null  int64
#  3   arrival_date_month              61913 non-null  object
#  4   arrival_date_week_number        61913 non-null  int64
#  5   arrival_date_day_of_month       61913 non-null  int64
#  6   stays_in_weekend_nights         61913 non-null  int64
#  7   stays_in_week_nights            61913 non-null  int64
#  8   adults                          61913 non-null  int64
#  9   children                        61909 non-null  float64
#  10  babies                          61913 non-null  int64
#  11  meal                            61913 non-null  object
#  12  country                         61692 non-null  object
#  13  market_segment                  61913 non-null  object
#  14  distribution_channel            61913 non-null  object
#  15  is_repeated_guest               61913 non-null  int64
#  16  previous_cancellations          61913 non-null  int64
#  17  previous_bookings_not_canceled  61913 non-null  int64
#  18  reserved_room_type              61913 non-null  object
#  19  assigned_room_type              61913 non-null  object
#  20  booking_changes                 61913 non-null  int64
#  21  deposit_type                    61913 non-null  object
#  22  agent                           54023 non-null  float64
#  23  company                         3152 non-null   float64
#  24  days_in_waiting_list            61913 non-null  int64
#  25  customer_type                   61913 non-null  object
#  26  adr                             61913 non-null  float64
#  27  required_car_parking_spaces     61913 non-null  int64
#  28  total_of_special_requests       61913 non-null  int64
#  29  reservation_status_date         61913 non-null  object
#  30  id                              61913 non-null  object
#  31  is_canceled                     61913 non-null  int64
# dtypes: float64(4), int64(16), object(12)
# memory usage: 15.1+ MB

# %% [markdown]
# ## a) Análisis exploratorio

# %% [markdown]
# V. Hotel

# %%
train['hotel'].value_counts()
# Out:
# City Hotel      42129
# Resort Hotel    19784
# Name: hotel, dtype: int64

# %%
v_hotel=snb.barplot(x='hotel', y= 'is_canceled', data=train).set_title('Tipo de hotel según cantidad de cancelaciones')

# %% [markdown]
# Mas del 60% de las reservas estudiadas son de City Hoteles. Las reservas canceladas son mayores en la misma categoría.

# %% [markdown]
# V. Mes de llegada

# %%
train['arrival_date_month'].value_counts()
# Out:
# August       7176
# July         6524
# May          6159
# April        5878
# October      5863
# June         5772
# September    5619
# March        4899
# February     4125
# December     3493
# November     3404
# January      3001
# Name: arrival_date_month, dtype: int64

# %%
bar_arrival_date_month=v_arrival_date_month.plot.bar(alpha=0.5 , title="Distribucion de frecuencia de mes de llegada" 
, xlabel="" , ylabel="Mes")

# %%
pd.crosstab( train['is_canceled'],train['arrival_date_month'])
# Out:
# arrival_date_month  April  August  December  February  January  July  June  \
# is_canceled
# 0                    2751    3564      1806      2228     1735  3185  2603
# 1                    3127    3612      1687      1897     1266  3339  3169
#
# arrival_date_month  March   May  November  October  September
# is_canceled
# 0                    2680  2895      1921     2894       2710
# 1                    2219  3264      1483     2969       2909

# %% [markdown]
# El periodo de mayores reservas son de mayo a octubre.

# %%
train['lead_time'].describe()
# Out:
# count    61913.000000
# mean       112.248187
# std        110.717953
# min          0.000000
# 25%         23.000000
# 50%         78.000000
# 75%        172.000000
# max        629.000000
# Name: lead_time, dtype: float64

# %%
v_lead_time_hist= snb.histplot(data=train['lead_time']).set_title('Frecuencia de dias transcurridos desde la fecha de reserva a la de llegada')

# %%
v_lead_time_box=snb.boxplot(data=train['lead_time']).set_title('Boxplot de dias transcurridos desde la fecha de reserva a la de llegada')

# %% [markdown]
# En promedio, las reservas se realizan con 112 días de anticipación a la fecha de arribo. Pero la mayor cantidad de reservas se realizan en el mismo día de llegada y con un maximo de 629 días.

# %% [markdown]
# # b)Visualización de datos

# %% [markdown]
# # c)Datos Faltantes

# %%
train.isnull()
# Out:
#        hotel  lead_time  arrival_date_year  arrival_date_month  \
# 0      False      False              False               False
# 1      False      False              False               False
# 2      False      False              False               False
# 3      False      False              False               False
# 4      False      False              False               False
# ...      ...        ...                ...                 ...
# 61908  False      False              False               False
# 61909  False      False              False               False
# 61910  False      False              False               False
# 61911  False      False              False               False
# 61912  False      False              False               False
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# 0                         False                      False
# 1                         False                      False
# 2                         False                      False
# 3                         False                      False
# 4                         False                      False
# ...                         ...                        ...
# 61908                     False                      False
# 61909                     False                      False
# 61910                     False                      False
# 61911                     False                      False
# 61912                     False                      False
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  children  ...  \
# 0                        False                 False   False     False  ...
# 1                        False                 False   False     False  ...
# 2                        False                 False   False     False  ...
# 3                        False                 False   False     False  ...
# 4                        False                 False   False     False  ...
# ...                        ...                   ...     ...       ...  ...
# 61908                    False                 False   False     False  ...
# 61909                    False                 False   False     False  ...
# 61910                    False                 False   False     False  ...
# 61911                    False                 False   False     False  ...
# 61912                    False                 False   False     False  ...
#
#        agent  company  days_in_waiting_list  customer_type    adr  \
# 0      False     True                 False          False  False
# 1       True     True                 False          False  False
# 2      False     True                 False          False  False
# 3      False     True                 False          False  False
# 4      False     True                 False          False  False
# ...      ...      ...                   ...            ...    ...
# 61908  False     True                 False          False  False
# 61909   True     True                 False          False  False
# 61910   True    False                 False          False  False
# 61911  False     True                 False          False  False
# 61912  False     True                 False          False  False
#
#        required_car_parking_spaces  total_of_special_requests  \
# 0                            False                      False
# 1                            False                      False
# 2                            False                      False
# 3                            False                      False
# 4                            False                      False
# ...                            ...                        ...
# 61908                        False                      False
# 61909                        False                      False
# 61910                        False                      False
# 61911                        False                      False
# 61912                        False                      False
#
#        reservation_status_date     id  is_canceled
# 0                        False  False        False
# 1                        False  False        False
# 2                        False  False        False
# 3                        False  False        False
# 4                        False  False        False
# ...                        ...    ...          ...
# 61908                    False  False        False
# 61909                    False  False        False
# 61910                    False  False        False
# 61911                    False  False        False
# 61912                    False  False        False
#
# [61913 rows x 32 columns]

# %%
for column in train.columns:
    percentage = train[column].isnull().mean()
    print(column +' : '+ str(round(percentage*100,2))+ ' %')
# Out:
# hotel : 0.0 %
# lead_time : 0.0 %
# arrival_date_year : 0.0 %
# arrival_date_month : 0.0 %
# arrival_date_week_number : 0.0 %
# arrival_date_day_of_month : 0.0 %
# stays_in_weekend_nights : 0.0 %
# stays_in_week_nights : 0.0 %
# adults : 0.0 %
# children : 0.01 %
# babies : 0.0 %
# meal : 0.0 %
# country : 0.36 %
# market_segment : 0.0 %
# distribution_channel : 0.0 %
# is_repeated_guest : 0.0 %
# previous_cancellations : 0.0 %
# previous_bookings_not_canceled : 0.0 %
# reserved_room_type : 0.0 %
# assigned_room_type : 0.0 %
# booking_changes : 0.0 %
# deposit_type : 0.0 %
# agent : 12.74 %
# company : 94.91 %
# days_in_waiting_list : 0.0 %
# customer_type : 0.0 %
# adr : 0.0 %
# required_car_parking_spaces : 0.0 %
# total_of_special_requests : 0.0 %
# reservation_status_date : 0.0 %
# id : 0.0 %
# is_canceled : 0.0 %
