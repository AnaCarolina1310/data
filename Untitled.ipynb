# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
# !pip install opendatasets --quiet

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import opendatasets as od 
dataset_url = 'https://www.kaggle.com/datasets/mohithsairamreddy/salary-data'
od.download(dataset_url)
# Out:
# Skipping, found downloaded files in ".\salary-data" (use force=True to force download)

# %%
df = pd.read_csv('.\salary_data.csv')
df.head(5)
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
df.shape
# Out:
# (6704, 6)

# %%
df.dtypes
# Out:
# Age                    float64
# Gender                  object
# Education Level         object
# Job Title               object
# Years of Experience    float64
# Salary                 float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Education Level', 'Job Title', 'Years of Experience',
#        'Salary'],
#       dtype='object')

# %%
df.isnull().sum().sort_values(ascending= False)
# Out:
# Salary                 5
# Education Level        3
# Years of Experience    3
# Age                    2
# Gender                 2
# Job Title              2
# dtype: int64

# %%
df.dropna(subset = ['Age', 'Gender', 'Education Level', 'Job Title', 'Years of Experience',
       'Salary'], inplace = True)

# %%
df['Age'] = df['Age'].astype(int)
df.loc[(df['Age'] >= 20 )& (df['Age'] <= 30), 'Age Group'] = '20 to 30'
df.loc[(df['Age'] > 30)& (df['Age'] <= 50), 'Age Group'] = '40 to 50'
df.loc[(df['Age'] > 50)& (df['Age'] <= 60), 'Age Group'] = '50 to 60'
df.loc[(df['Age'] > 60), 'Age Group'] = 'more than 60'

# %%
df['Years of Experience'] = df['Years of Experience'].astype(int)
df['Salary'] = df['Salary'].astype(int)

# %%
df.loc[(df['Years of Experience'] <=2 ), 'Seniority'] = 'Junior'
df.loc[(df['Years of Experience'] > 2)& (df['Years of Experience'] <= 6), 'Seniority'] = 'Semi senior'
df.loc[df['Years of Experience'] > 6, 'Seniority'] = 'Senior'

# %%
df.head(5)
# Out:
#    Age  Gender Education Level          Job Title  Years of Experience  \
# 0   32    Male      Bachelor's  Software Engineer                    5
# 1   28  Female        Master's       Data Analyst                    3
# 2   45    Male             PhD     Senior Manager                   15
# 3   36  Female      Bachelor's    Sales Associate                    7
# 4   52    Male        Master's           Director                   20
#
#    Salary Age Group    Seniority
# 0   90000  40 to 50  Semi senior
# 1   65000  20 to 30  Semi senior
# 2  150000  40 to 50       Senior
# 3   60000  40 to 50       Senior
# 4  200000  50 to 60       Senior

# %% [markdown]
# # Average salary by age group

# %%
mean_salary_age_group=df.groupby('Age Group')[['Salary']]
mean_salary_age_group=round(mean_salary_age_group.mean(), 2)
mean_salary_age_group.plot(kind='line')
# Out:
# <AxesSubplot:xlabel='Age Group'>

# %% [markdown]
# # Average salary by seniority

# %%
mean_salary_seniority=df.groupby('Seniority')[['Salary']]
mean_salary_seniority=round(mean_salary_seniority.mean(), 2)
mean_salary_seniority.plot(kind='line')
# Out:
# <AxesSubplot:xlabel='Seniority'>

# %% [markdown]
# # Average salary by age gender

# %%
mean_salary_gender=df.groupby('Gender')[['Salary']]
mean_salary_gender=round(mean_salary_gender.mean(), 2)
mean_salary_gender.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Gender'>

# %% [markdown]
# # Average salary by education level

# %%
mean_salary_education_level=df.groupby('Education Level')[['Salary']]
mean_salary_education_level=round(mean_salary_education_level.mean(), 2).sort_values(by='Salary', ascending=False)
mean_salary_education_level.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Education Level'>

# %% [markdown]
# # Average salary by job title: the three highest and lowest positions

# %%
mean_salary_job=df.groupby('Job Title')[['Salary']]
mean_salary_job=round(mean_salary_job.mean(), 2).sort_values(by='Salary', ascending=False).reset_index()

fig, (ax1,ax2) = plt.subplots(1,2, figsize= (18,4))
ax1.bar(mean_salary_job['Job Title'].head(3),mean_salary_job['Salary'].head(3))
ax2.bar(mean_salary_job['Job Title'].tail(3),mean_salary_job['Salary'].tail(3))
# Out:
# <BarContainer object of 3 artists>
